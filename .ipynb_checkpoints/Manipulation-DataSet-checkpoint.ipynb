# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('./Output/SharckAttack_dfClean.csv')

# %%
display(df)
# Out:
#        Case Number           Date  Year        Type       Country  \
# 0     2016.09.18.c      18-Sep-16  2016  Unprovoked           USA
# 1     2016.09.18.b      18-Sep-16  2016  Unprovoked           USA
# 2     2016.09.18.a      18-Sep-16  2016  Unprovoked           USA
# 3       2016.09.17      17-Sep-16  2016  Unprovoked     AUSTRALIA
# 4       2016.09.15      16-Sep-16  2016  Unprovoked     AUSTRALIA
# ...            ...            ...   ...         ...           ...
# 5307    1900.07.14      14-Jul-00  1900     Invalid           USA
# 5308    1900.07.00  Late Jul-1900  1900    Provoked           USA
# 5309    1900.01.28    28-Jan-1900  1900  Unprovoked     AUSTRALIA
# 5310  1900.00.00.b    Early 1900s  1900  Unprovoked           USA
# 5311  1900.00.00.a       Ca. 1900  1900  Unprovoked  SOUTH AFRICA
#
#                          Activity Sex   Age  \
# 0                         Surfing    M   16
# 1                         Surfing    M   36
# ...

# %%
'''Estudiamos si en los últimos años han sobrevivido más  personas a los ataques de tiburón.'''
años=df['Year'].value_counts().sort_index()

cutoffs = list(range(1900,2035,15))
year_labels = ['1900-15', '1915-30', '1930-45', '1945-60', '1960-75','1975-90','1990-05','2005-20']
bins = pd.cut("Year",cutoffs, labels=year_labels)
df["Year"] = bins
#cutoffs
bins
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-a91355b8d5d7> in <module>
#       4 cutoffs = list(range(1900,2035,15))
#       5 year_labels = ['1900-15', '1915-30', '1930-45', '1945-60', '1960-75','1975-90','1990-05','2005-20']
# ----> 6 bins = pd.cut("Year",cutoffs, labels=year_labels)
#       7 df["Year"] = bins
#       8 #cutoffs
#
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     209
#     210     # for handling the cut for datetime and timedelta objects
# --> 211     x_is_series, series_index, name, x = _preprocess_for_cut(x)
#     212     x, dtype = _coerce_to_type(x)
#     213
#
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/tile.py in _preprocess_for_cut(x)
#     552         x = np.asarray(x)
#     553     if x.ndim != 1:
# ...

# %%
df2=df[['Year','Country','Activity','Sex ','Age','Fatal (Y/N)']]
d_C=df2.groupby(['Country']).count()
d_Y=df2.groupby(['Year']).count()
d_A=df2.groupby(['Activity']).count()
print(df2.shape)
display(d_C)
display(d_A)
# Out:
# (5312, 6)
#                             Year  Activity  Sex   Age  Fatal (Y/N)
# Country
#  PHILIPPINES                   1         1     1    0            1
#  TONGA                         3         3     3    1            3
# ADMIRALTY ISLANDS              1         0     1    1            1
# AMERICAN SAMOA                 3         3     3    3            3
# ANDAMAN / NICOBAR ISLANDAS     1         1     1    1            1
# ...                          ...       ...   ...  ...          ...
# VENEZUELA                      9         7     9    4            9
# VIETNAM                       11         8    11    6           11
# WESTERN SAMOA                  1         1     1    1            1
# YEMEN                          2         2     1    0            2
# YEMEN                          2         2     2    0            2
#
# [174 rows x 5 columns]
#                                                     Year  Country  Sex   Age  \
# Activity
# ...

# %%
df2[(df2['Country']=='TONGA')]
# Out:
#       Year Country                                         Activity Sex   Age  \
# 515   2012   TONGA                                         Swimming    F   29
# 765   2010   TONGA                       Swimming /  Whale Watching    M   24
# 1279  2006   TONGA                                         Swimming    F   24
# 1600  2002   TONGA                                         Swimming    M
# 2130  1995   TONGA                                          Fishing    M   18
# 2136  1995   TONGA                                          Fishing    M  NaN
# 2280  1993   TONGA                                     Sea disaster    M  NaN
# 2281  1993   TONGA                                     Sea disaster    M  NaN
# 2289  1993   TONGA                                     Spearfishing  NaN   30
# 2856  1980   TONGA                                     Spearfishing    M  20s
# 3272  1967   TONGA                                         Swimming    M   17
# ...

# %%
df2.groupby('Sex ')['Country'].nunique().plot(kind='bar')
plt.show()

# %%
df[['Year']].plot(kind='hist',bins=list(range(1900,2035,15)),rwidth=0.8)
plt.show()

# %%
df.groupby('Year')['Sex '].nunique().plot(kind='bar')
plt.show()
