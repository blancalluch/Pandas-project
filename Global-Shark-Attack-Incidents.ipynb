# %%
import pandas as pd 
import getpass

# %%
df=pd.read_csv("./Input/GSAF5.csv", encoding="UTF-8")
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 1: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-8904b13c49ad> in <module>
# ----> 1 df=pd.read_csv("./Input/GSAF5.csv", encoding="UTF-8")
#       2 df.head(10)
#
# ...

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
null_cols = df.isnull().sum()
print(null_cols[null_cols > 0])
df.size
# Out:
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# href formula                 1
# href                         3
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64
# 143808

# %%
'''
Elegimos las columnas con datos relevantes a mi estudio. Los pdf, columnas repetidas y los 
nombres de las personas afectadas no me interesan,por ello las eliminamos.
'''
drop_cols = ['Name', 'pdf', 'href formula', 'href',
       'Case Number.1', 'Case Number.2', 'Unnamed: 22','Unnamed: 23']
data_f = df.drop(drop_cols, axis=1)
data_f.head(10)
# Out:
#     Case Number       Date  Year        Type        Country  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked            USA
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked            USA
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked            USA
# 3    2016.09.17  17-Sep-16  2016  Unprovoked      AUSTRALIA
# 4    2016.09.15  16-Sep-16  2016  Unprovoked      AUSTRALIA
# 5  2016.09.15.R  15-Sep-16  2016        Boat      AUSTRALIA
# 6    2016.09.11  11-Sep-16  2016  Unprovoked            USA
# 7    2016.09.07  07-Sep-16  2016  Unprovoked            USA
# 8    2016.09.06  06-Sep-16  2016  Unprovoked  NEW CALEDONIA
# 9  2016.09.05.b  05-Sep-16  2016  Unprovoked            USA
#
#                 Area                                         Location  \
# 0            Florida                 New Smyrna Beach, Volusia County
# 1            Florida                 New Smyrna Beach, Volusia County
# 2            Florida                 New Smyrna Beach, Volusia County
# ...

# %%
null_displ = data_f[(data_f['Country'].isnull()==True)]
null_displ = null_displ[['Year', 'Area','Location','Country','Sex ']]
null_displ
# Out:
#       Year                                           Area  \
# 303   2014                                            NaN
# 2731  1983                                English Channel
# 3153  1970                                            NaN
# 3162  1970                                  Caribbean Sea
# 3163  1970                                            NaN
# 3170  1970                                            NaN
# 3174  1970                                            NaN
# 3200  1969                                            NaN
# 3379  1965                                            NaN
# 3435  1964                                            NaN
# 3792  1960              Between Timor & Darwin, Australia
# 4005  1956             Near the Andaman & Nicobar Islands
# 4040  1956                   Between Comores & Madagascar
# 4271  1949                                  Caribbean Sea
# 4412  1944                                            NaN
# ...

# %%
null
